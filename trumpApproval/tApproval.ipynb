# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('approval_topline.csv')

# %%
df = df.loc[df['subgroup'] == 'Voters']

# %%
df = df.iloc[::-1]

# %%
x = df['modeldate']
y = df['approve_estimate']
plt.ylabel('Approval %')
plt.plot(x,y)
