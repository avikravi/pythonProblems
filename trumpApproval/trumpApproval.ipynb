# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('approval_topline.csv')

# %%
df
# Out:
#          president   subgroup  modeldate  approve_estimate  approve_hi  \
# 0     Donald Trump     Voters  3/31/2020         45.996725   50.393851
# 1     Donald Trump     Adults  3/31/2020         45.555048   50.577556
# 2     Donald Trump  All polls  3/31/2020         45.418363   49.933597
# 3     Donald Trump     Adults  3/30/2020         45.668993   50.721005
# 4     Donald Trump     Voters  3/30/2020         45.855167   50.266664
# ...            ...        ...        ...               ...         ...
# 3487  Donald Trump     Adults  1/24/2017         45.000000   50.985620
# 3488  Donald Trump  All polls  1/24/2017         45.442640   50.829220
# 3489  Donald Trump  All polls  1/23/2017         45.466930   50.889710
# 3490  Donald Trump     Adults  1/23/2017         45.000000   51.134700
# 3491  Donald Trump     Voters  1/23/2017         46.000000   52.292380
#
#       approve_lo  disapprove_estimate  disapprove_hi  disapprove_lo  \
# ...

# %%
df = df.loc[df['subgroup'] == 'Voters'].head(5)

# %%
df = df.iloc[::-1]

# %%
x = df['modeldate']
y = df['approve_estimate']
plt.plot(x,y)
