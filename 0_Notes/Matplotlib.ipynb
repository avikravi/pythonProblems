# %% [markdown]
# # MATPLOTLIB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
matplotlib.style.use('seaborn-white')
fig, ax = plt.subplots()

# %%
a = [1,3,7,8,2,3,4,5,6,7,8,5,1,7,2,3,7,9,10]

# %%
b = [1,4,2,1,6,3,4,5,6,7,4,3,2,6,7,9,8,9,10]
c = [911, 12, 13, 14]

# %%
fig = plt.scatter(a,b,s=c)
